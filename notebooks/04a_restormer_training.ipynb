# %%
# --------------------------------
# Imports & Path Setup
# --------------------------------

# %reload_ext autoreload
# %autoreload 2

import os
print(os.getcwd())

import sys
from pathlib import Path
sys.path.append(str(Path("..").resolve()))

import numpy as np
import matplotlib.pyplot as plt
import torch
from skimage.metrics import peak_signal_noise_ratio as calc_psnr
from skimage.metrics import structural_similarity as calc_ssim

from src.models.restormer import RestormerModel

from src.utils.trainer import Trainer
from src.utils.logger import Logger
# Out:
# /hpc/home/efavale/deep-image-restoration

# %%
# --------------------------------
# Trainer Setup
# --------------------------------

LOG_DIR = Path("logs")

RESIZED_DIR = Path("data/resized")
COMPRESSED_DIR = Path("data/compressed")
CHECKPOINTS_DIR = Path("checkpoints")

logger = Logger(
    dir=LOG_DIR,
    description="RestormerModel-BothCompressions"
)

model = RestormerModel(logger=logger)

# RestormerModel
trainer = Trainer(
    input_dir=RESIZED_DIR,
    compressed_dir=COMPRESSED_DIR,
    checkpoints_dir=CHECKPOINTS_DIR,
    checkpoint_name="best_model_restormer",
    model=model,
    batch_size=4,
    learning_rate=1e-3,
    weight_decay=1e-4,
)

trainer.load_dataset()
# Out:
# Device : cpu
# Parameters : 26,126,644
# Train	| Val	| Test :
# 700	| 150	| 150

# %%
# --------------------------------
# Training
# --------------------------------

history = trainer.train(num_epochs=50)
# Out:
# Epoch   1/50  |  Train Loss: 0.304909  |  Val Loss:   0.112303
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 5
#       1 # --------------------------------
#       2 # Training
#       3 # --------------------------------
# ----> 5 history = trainer.train(num_epochs=50)
#
# File ~/deep-image-restoration/src/utils/trainer.py:333, in Trainer.train(self, num_epochs)
#     330 best_epoch = -1
#     332 for epoch in range(1, num_epochs + 1):
# --> 333     avg_train_loss = self._train_epoch()
#     334     avg_val_loss = self._validate_epoch()
#     335     self.scheduler.step()
#
# File ~/deep-image-restoration/src/utils/trainer.py:274, in Trainer._train_epoch(self)
#     272 recon, _ = self.model(compressed)
#     273 loss = self.criterion(recon, original)
# --> 274 loss.backward()
#     275 self.optimizer.step()
#     276 total_loss += loss.item()
#
# File ~/miniconda3/envs/deep-image-restoration/lib/python3.12/site-packages/torch/_tensor.py:630, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     620 if has_torch_function_unary(self):
#     621     return handle_torch_function(
#     622         Tensor.backward,
#     623         (self,),
#    (...)    628         inputs=inputs,
#     629     )
# --> 630 torch.autograd.backward(
#     631     self, gradient, retain_graph, create_graph, inputs=inputs
#     632 )
#
# File ~/miniconda3/envs/deep-image-restoration/lib/python3.12/site-packages/torch/autograd/__init__.py:364, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     359     retain_graph = create_graph
#     361 # The reason we repeat the same comment below is that
#     362 # some Python versions print out the first line of a multi-line function
#     363 # calls in the traceback and some print out the last line
# --> 364 _engine_run_backward(
#     365     tensors,
#     366     grad_tensors_,
#     367     retain_graph,
#     368     create_graph,
#     369     inputs_tuple,
#     370     allow_unreachable=True,
#     371     accumulate_grad=True,
#     372 )
#
# File ~/miniconda3/envs/deep-image-restoration/lib/python3.12/site-packages/torch/autograd/graph.py:865, in _engine_run_backward(t_outputs, *args, **kwargs)
#     863     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     864 try:
# --> 865     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     866         t_outputs, *args, **kwargs
#     867     )  # Calls into the C++ engine to run the backward pass
#     868 finally:
#     869     if attach_logging_hooks:
#
# KeyboardInterrupt:

# %%
# --------------------------------
# Loss Curves
# --------------------------------

epochs = range(1, len(history["train_loss"]) + 1)

plt.figure(figsize=(9, 4))
plt.plot(epochs, history["train_loss"], label="Train Loss", color="steelblue")
plt.plot(epochs, history["val_loss"], label="Val Loss", color="darkorange")
plt.xlabel("Epoch")
plt.ylabel("Train Loss (MSE + Perceptual)")
plt.title("Loss Curves — CAE Baseline")
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 5
#       1 # --------------------------------
#       2 # Loss Curves
#       3 # --------------------------------
# ----> 5 epochs = range(1, len(history["train_loss"]) + 1)
#       7 plt.figure(figsize=(9, 4))
#       8 plt.plot(epochs, history["train_loss"], label="Train Loss", color="steelblue")
#
# NameError: name 'history' is not defined

# %%
# --------------------------------
# Load Best Checkpoint
# --------------------------------

trainer.model.load_state_dict(
    torch.load(
        Path("checkpoints/best_model_restormer_20260327_122913.pth"), map_location=trainer.device
    )
)
trainer.model.eval()
print(" Best model loaded")
# Out:
#  Best model loaded

# %%
# --------------------------------
# Baseline PSNR — Compressed vs Original
# --------------------------------

psnr_baseline, ssim_baseline = [], []

for compressed, original in trainer.test_loader:
    for comp_t, orig_t in zip(compressed.numpy(), original.numpy()):
        comp_np = np.transpose(comp_t, (1, 2, 0))
        orig_np = np.transpose(orig_t, (1, 2, 0))
        psnr_baseline.append(calc_psnr(orig_np, comp_np, data_range=1.0))
        ssim_baseline.append(
            calc_ssim(orig_np, comp_np, data_range=1.0, channel_axis=2)
        )

psnr_base = np.mean(psnr_baseline)
ssim_base = np.mean(ssim_baseline)
print(f"Baseline  —  PSNR: {psnr_base:.2f} dB  |  SSIM: {ssim_base:.4f}")
# Out:
# Baseline  —  PSNR: 25.60 dB  |  SSIM: 0.7883

# %%
# --------------------------------
# PSNR / SSIM — Restored vs Original
# --------------------------------

psnr_list, ssim_list = [], []

with torch.no_grad():
    for compressed, original in trainer.test_loader:
        compressed = compressed.to(trainer.device)
        original = original.to(trainer.device)
        recon, _ = trainer.model(compressed)

        for out_t, orig_t in zip(recon.cpu().numpy(), original.cpu().numpy()):
            out_np = np.transpose(out_t, (1, 2, 0))
            orig_np = np.transpose(orig_t, (1, 2, 0))
            psnr_list.append(calc_psnr(orig_np, out_np, data_range=1.0))
            ssim_list.append(calc_ssim(orig_np, out_np, data_range=1.0, channel_axis=2))

psnr_mean = np.mean(psnr_list)
ssim_mean = np.mean(ssim_list)

print(f"{'─' * 50}")
print(f"  PSNR baseline (compressed) : {psnr_base:.2f} dB")
print(
    f"  PSNR restored              : {psnr_mean:.2f} dB  ({psnr_mean - psnr_base:+.2f})"
)
print(f"  SSIM baseline (compressed) : {ssim_base:.4f}")
print(f"  SSIM restored              : {ssim_mean:.4f}  ({ssim_mean - ssim_base:+.4f})")
print(f"{'─' * 50}")
# Out:
# ──────────────────────────────────────────────────
#   PSNR baseline (compressed) : 25.60 dB
#   PSNR restored              : 28.55 dB  (+2.95)
#   SSIM baseline (compressed) : 0.7883
#   SSIM restored              : 0.8138  (+0.0255)
# ──────────────────────────────────────────────────
# Si è verificato un arresto anomalo del Kernel durante l'esecuzione del codice nella cella attiva o in una cella precedente.
#
# Esaminare il codice nelle celle per identificare una possibile causa dell'errore.
#
# Per altre informazioni, fare clic<a href='https://aka.ms/vscodeJupyterKernelCrash'>qui</a>.
#
# Per ulteriori dettagli, visualizzare Jupyter <a href='command:jupyter.viewOutput'>log</a>.
